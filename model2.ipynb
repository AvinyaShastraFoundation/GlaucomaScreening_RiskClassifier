# %%
import numpy as np
import pandas as pd  
import matplotlib.pyplot as plt 
from kmodes.kprototypes import KPrototypes   
#import json
import csv 
city=['Hyderbad','Vijayawada','Vizag','Chennai','Delhi','Goa','Banglore'] 
x=["PATIENT_ID", "CITY","GENDER","AGE"]
e=int(input("Total Patients: "))
p=len(x)
z={}
f=open('Qbook1.csv')
r=csv.DictReader (f)
r=0
for i in f:
    if r>0:
        x.append(i)
    r=r+1
x.append("IOP")
for i in range(e):
    a=np.random.randint (333669, 674669)
    z.setdefault(x[0], []).append(int(a))
    b=np .random. choice (city, size=1)
    z.setdefault(x[1], []).append("".join(b))
    c=np.random. choice(["Male", "Female"], size=1)
    z.setdefault(x[2],[]).append("".join(c))
    d=np.random. randint (80) 
    z.setdefault(x[3],[]).append(d)
for i in range(e):
    for j in range(10):
        k=np.random.choice(["Yes", "No"],size=1)  
        z.setdefault(x[p], []).append("".join(k))
        p=p+1
    p=4 
for i in range(e):
    n=np.random.randint (8,40)
    z.setdefault(x[len(x)-1], []).append(n)
         # displaying the IOP range 
    k="BETTER TO CONSULT A DOCTOR" 
    l="NEED A CHECKUP"
    o="EMERGENCY"
    if n>=8 and n<=20 :
        m=k
    elif n>20 and n<=30: 
        m=l
    else :
        m=o
    z.setdefault("suggestion",[]).append(m)   
df=pd.DataFrame(z)
cp=df[["suggestion","IOP"]]  
array=cp.values  
array[:,1]=array[:,1].astype(float)   
kproto=KPrototypes(n_clusters=3,verbose=2,max_iter=12) 
clusters=kproto.fit_predict(array,categorical=[0])  
for i in clusters: 
    z.setdefault("clusters",[]).append(i)   
df=pd.DataFrame(z)    
print(df)
for i in range(len(city)): 
    plt.bar(city[i],len(df[(df["CITY"]==city[i]) & (df["clusters"] ==0)]),color="red",width=0.4) 
    plt.bar(city[i],len(df[(df["CITY"]==city[i]) & (df["clusters"] ==1)]),color="blue",width=0.28) 
    plt.bar(city[i],len(df[(df["CITY"]==city[i]) & (df["clusters"] ==2)]),color="green",width=0.19) 
plt.ylabel("No of Patients",color="red") 
plt.legend(["cluster-0","cluster-1","cluster-2"])
def myconverter(obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        elif isinstance(obj, datetime.datetime):
            return obj.__str__()

with open('test.json','w') as f: 
 y=json.dump(z,f,default=myconverter)
# Out:
# /opt/intel/inteloneapi/intelpython/latest/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)
# Total Patients:  10
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/12, moves: 1, ncost: 40.51992063367083
# Run: 1, iteration: 2/12, moves: 1, ncost: 34.219920633670824
# Run: 1, iteration: 3/12, moves: 0, ncost: 34.219920633670824
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/12, moves: 3, ncost: 34.219920633670824
# Run: 2, iteration: 2/12, moves: 0, ncost: 34.219920633670824
# Init: initializing centroids
# ...
