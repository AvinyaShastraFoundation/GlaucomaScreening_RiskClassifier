# %%
import numpy as np
import pandas as pd  
import matplotlib.pyplot as plt 
from kmodes.kprototypes import KPrototypes   
import json
import csv 
city=['Hyderbad','Vijayawada','Vizag','Chennai','Delhi','Goa','Banglore'] 
x=["PATIENT_ID", "CITY","GENDER","AGE"]
e=int(input("Total Patients: "))
p=len(x)
z={}
f=open('Qbook1.csv')
r=csv.DictReader (f)
r=0
for i in f:
    if r>0:
        x.append(i)
    r=r+1
x.append("IOP")
for i in range(e):
    a=np.random.randint (333669, 674669)
    z.setdefault(x[0], []).append(int(a))
    b=np .random. choice (city, size=1)
    z.setdefault(x[1], []).append("".join(b))
    c=np.random. choice(["Male", "Female"], size=1)
    z.setdefault(x[2],[]).append("".join(c))
    d=np.random. randint (80) 
    z.setdefault(x[3],[]).append(d)
for i in range(e):
    for j in range(10):
        k=np.random.choice(["Yes", "No"],size=1)  
        z.setdefault(x[p], []).append("".join(k))
        p=p+1
    p=4 
for i in range(e):
    n=np.random.randint (8,40)
    z.setdefault(x[len(x)-1], []).append(n)
         # displaying the IOP range 
    k="BETTER TO CONSULT A DOCTOR" 
    l="NEED A CHECKUP"
    o="EMERGENCY"
    if n>=8 and n<=20 :
        m=k
    elif n>20 and n<=30: 
        m=l
    else :
        m=o
    z.setdefault("suggestion",[]).append(m)   
df=pd.DataFrame(z)
cp=df[["suggestion","IOP"]]  
array=cp.values  
array[:,1]=array[:,1].astype(float)   
kproto=KPrototypes(n_clusters=3,verbose=2,max_iter=12) 
clusters=kproto.fit_predict(array,categorical=[0])  
for i in clusters: 
    z.setdefault("clusters",[]).append(i)   
df=pd.DataFrame(z)    
print(df)
for i in range(len(city)): 
    plt.bar(city[i],len(df[(df["CITY"]==city[i]) & (df["clusters"] ==0)]),color="red",width=0.4) 
    plt.bar(city[i],len(df[(df["CITY"]==city[i]) & (df["clusters"] ==1)]),color="blue",width=0.28) 
    plt.bar(city[i],len(df[(df["CITY"]==city[i]) & (df["clusters"] ==2)]),color="green",width=0.19) 
plt.ylabel("No of Patients",color="red") 
plt.legend(["cluster-0","cluster-1","cluster-2"])
def myconverter(obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        elif isinstance(obj, datetime.datetime):
            return obj.__str__()

with open('test.json','w') as f: 
 y=json.dump(z,f,default=myconverter)
# Out:
# Total Patients:  30
# Initialization method and algorithm are deterministic. Setting n_init to 1.
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/12, moves: 4, ncost: 240.67631256504464
# Run: 1, iteration: 2/12, moves: 2, ncost: 232.863148456426
# Run: 1, iteration: 3/12, moves: 0, ncost: 232.863148456426
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/12, moves: 4, ncost: 399.2672216559538
# Run: 2, iteration: 2/12, moves: 7, ncost: 238.61182843806054
# Run: 2, iteration: 3/12, moves: 1, ncost: 232.863148456426
# Run: 2, iteration: 4/12, moves: 0, ncost: 232.863148456426
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/12, moves: 6, ncost: 238.61182843806054
# Run: 3, iteration: 2/12, moves: 1, ncost: 232.863148456426
# Run: 3, iteration: 3/12, moves: 0, ncost: 232.863148456426
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/12, moves: 4, ncost: 238.61182843806054
# Run: 4, iteration: 2/12, moves: 1, ncost: 232.863148456426
# Run: 4, iteration: 3/12, moves: 0, ncost: 232.863148456426
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/12, moves: 8, ncost: 322.61645434436815
# Run: 5, iteration: 2/12, moves: 3, ncost: 266.9566537725749
# Run: 5, iteration: 3/12, moves: 2, ncost: 243.91057691587784
# Run: 5, iteration: 4/12, moves: 1, ncost: 237.1478972878136
# Run: 5, iteration: 5/12, moves: 0, ncost: 237.1478972878136
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/12, moves: 4, ncost: 265.1191540557091
# Run: 6, iteration: 2/12, moves: 2, ncost: 239.441521472299
# Run: 6, iteration: 3/12, moves: 1, ncost: 232.863148456426
# Run: 6, iteration: 4/12, moves: 0, ncost: 232.863148456426
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/12, moves: 7, ncost: 240.67631256504464
# Run: 7, iteration: 2/12, moves: 2, ncost: 232.863148456426
# Run: 7, iteration: 3/12, moves: 0, ncost: 232.863148456426
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/12, moves: 6, ncost: 307.32271712835524
# Run: 8, iteration: 2/12, moves: 2, ncost: 266.9566537725749
# Run: 8, iteration: 3/12, moves: 2, ncost: 243.91057691587784
# Run: 8, iteration: 4/12, moves: 1, ncost: 237.1478972878136
# Run: 8, iteration: 5/12, moves: 0, ncost: 237.1478972878136
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/12, moves: 6, ncost: 238.61182843806054
# Run: 9, iteration: 2/12, moves: 1, ncost: 232.863148456426
# Run: 9, iteration: 3/12, moves: 0, ncost: 232.863148456426
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/12, moves: 10, ncost: 238.61182843806054
# Run: 10, iteration: 2/12, moves: 1, ncost: 232.863148456426
# Run: 10, iteration: 3/12, moves: 0, ncost: 232.863148456426
# Best run was number 1
#     PATIENT_ID        CITY  GENDER  AGE  \
# 0       411651    Hyderbad    Male   19
# 1       418358         Goa    Male   64
# 2       441438       Vizag  Female   12
# 3       417187       Delhi    Male    8
# 4       521515       Vizag  Female   50
# 5       556230    Banglore  Female    8
# 6       369308       Delhi    Male   16
# 7       418587    Banglore  Female   48
# 8       400689     Chennai    Male   51
# 9       461218         Goa    Male   11
# 10      636930         Goa  Female   77
# 11      361475       Vizag  Female   26
# 12      609174    Hyderbad  Female   53
# 13      631238     Chennai    Male   39
# 14      570785    Banglore    Male    0
# 15      534896     Chennai    Male   48
# 16      632476    Hyderbad    Male    6
# 17      614155     Chennai  Female   23
# 18      427104       Vizag  Female   32
# 19      645968       Vizag    Male    6
# 20      420227       Delhi  Female   68
# 21      614363    Hyderbad    Male   59
# 22      568393    Banglore  Female   57
# 23      547517  Vijayawada  Female   10
# 24      532468         Goa    Male   16
# 25      378525       Vizag    Male   45
# 26      343356    Hyderbad    Male   39
# 27      610642  Vijayawada  Female    5
# 28      488206         Goa  Female   60
# 29      511943    Banglore    Male   57
#
#    1.Do you have family history of glaucoma / any blinding disease?\n  \
# 0                                                 Yes
# 1                                                  No
# 2                                                  No
# 3                                                 Yes
# 4                                                  No
# 5                                                  No
# 6                                                  No
# 7                                                 Yes
# 8                                                  No
# 9                                                 Yes
# 10                                                Yes
# 11                                                Yes
# 12                                                Yes
# 13                                                 No
# 14                                                Yes
# 15                                                 No
# 16                                                 No
# 17                                                 No
# 18                                                Yes
# 19                                                Yes
# 20                                                Yes
# 21                                                Yes
# 22                                                Yes
# 23                                                Yes
# 24                                                 No
# 25                                                 No
# 26                                                 No
# 27                                                Yes
# 28                                                Yes
# 29                                                 No
#
#    2. Do you have glasses with high minus power since childhood?\n  \
# 0                                                  No
# 1                                                  No
# 2                                                  No
# 3                                                  No
# 4                                                  No
# 5                                                  No
# 6                                                  No
# 7                                                  No
# 8                                                  No
# 9                                                  No
# 10                                                Yes
# 11                                                 No
# 12                                                 No
# 13                                                Yes
# 14                                                Yes
# 15                                                Yes
# 16                                                 No
# 17                                                Yes
# 18                                                 No
# 19                                                 No
# 20                                                 No
# 21                                                 No
# 22                                                 No
# 23                                                 No
# 24                                                 No
# 25                                                 No
# 26                                                 No
# 27                                                 No
# 28                                                Yes
# 29                                                 No
#
#    3. Do you have high plus power glasses since childhood?\n  \
# 0                                                 Yes
# 1                                                  No
# 2                                                  No
# 3                                                  No
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                  No
# 8                                                  No
# 9                                                  No
# 10                                                Yes
# 11                                                 No
# 12                                                 No
# 13                                                 No
# 14                                                 No
# 15                                                 No
# 16                                                Yes
# 17                                                Yes
# 18                                                 No
# 19                                                Yes
# 20                                                Yes
# 21                                                 No
# 22                                                Yes
# 23                                                Yes
# 24                                                 No
# 25                                                Yes
# 26                                                 No
# 27                                                 No
# 28                                                 No
# 29                                                Yes
#
#    4. Did you have any blunt trauma in your eye with a a ball or anything blunt?\n  \
# 0                                                  No
# 1                                                  No
# 2                                                 Yes
# 3                                                 Yes
# 4                                                  No
# 5                                                  No
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                  No
# 10                                                Yes
# 11                                                 No
# 12                                                Yes
# 13                                                 No
# 14                                                 No
# 15                                                Yes
# 16                                                Yes
# 17                                                 No
# 18                                                Yes
# 19                                                Yes
# 20                                                Yes
# 21                                                Yes
# 22                                                Yes
# 23                                                Yes
# 24                                                Yes
# 25                                                Yes
# 26                                                 No
# 27                                                 No
# 28                                                Yes
# 29                                                 No
#
#    5. Did you have any surgery in the eye for any cause?\n  \
# 0                                                 Yes
# 1                                                  No
# 2                                                 Yes
# 3                                                 Yes
# 4                                                  No
# 5                                                 Yes
# 6                                                  No
# 7                                                 Yes
# 8                                                  No
# 9                                                 Yes
# 10                                                 No
# 11                                                 No
# 12                                                 No
# 13                                                Yes
# 14                                                 No
# 15                                                 No
# 16                                                Yes
# 17                                                 No
# 18                                                Yes
# 19                                                Yes
# 20                                                 No
# 21                                                 No
# 22                                                Yes
# 23                                                Yes
# 24                                                 No
# 25                                                Yes
# 26                                                Yes
# 27                                                Yes
# 28                                                Yes
# 29                                                 No
#
#    6. Did you have any significant perinatal events with delayed milestones?\n  \
# 0                                                  No
# 1                                                  No
# 2                                                  No
# 3                                                 Yes
# 4                                                  No
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 Yes
# 8                                                 Yes
# 9                                                  No
# 10                                                 No
# 11                                                 No
# 12                                                Yes
# 13                                                 No
# 14                                                 No
# 15                                                 No
# 16                                                Yes
# 17                                                Yes
# 18                                                Yes
# 19                                                Yes
# 20                                                 No
# 21                                                 No
# 22                                                Yes
# 23                                                 No
# 24                                                Yes
# 25                                                 No
# 26                                                 No
# 27                                                Yes
# 28                                                 No
# 29                                                Yes
#
#    7. Do you have Diabetes mellitus?\n  \
# 0                                   No
# 1                                   No
# 2                                   No
# 3                                  Yes
# 4                                  Yes
# 5                                   No
# 6                                  Yes
# 7                                   No
# 8                                  Yes
# 9                                  Yes
# 10                                  No
# 11                                 Yes
# 12                                 Yes
# 13                                 Yes
# 14                                 Yes
# 15                                  No
# 16                                 Yes
# 17                                  No
# 18                                 Yes
# 19                                  No
# 20                                 Yes
# 21                                  No
# 22                                  No
# 23                                 Yes
# 24                                 Yes
# 25                                  No
# 26                                  No
# 27                                 Yes
# 28                                  No
# 29                                  No
#
#    8. Do you have Hypertension or heart related complications?\n  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                  No
# 6                                                  No
# 7                                                  No
# 8                                                 Yes
# 9                                                  No
# 10                                                Yes
# 11                                                 No
# 12                                                Yes
# 13                                                 No
# 14                                                Yes
# 15                                                 No
# 16                                                Yes
# 17                                                 No
# 18                                                Yes
# 19                                                Yes
# 20                                                 No
# 21                                                 No
# 22                                                Yes
# 23                                                 No
# 24                                                Yes
# 25                                                 No
# 26                                                 No
# 27                                                 No
# 28                                                Yes
# 29                                                Yes
#
#    9. Do you use any OTC drops for eye itching?(likely steroids)\n  \
# 0                                                 Yes
# 1                                                 Yes
# 2                                                  No
# 3                                                 Yes
# 4                                                 Yes
# 5                                                  No
# 6                                                  No
# 7                                                  No
# 8                                                 Yes
# 9                                                  No
# 10                                                 No
# 11                                                 No
# 12                                                 No
# 13                                                Yes
# 14                                                Yes
# 15                                                 No
# 16                                                Yes
# 17                                                 No
# 18                                                Yes
# 19                                                 No
# 20                                                 No
# 21                                                Yes
# 22                                                 No
# 23                                                 No
# 24                                                Yes
# 25                                                 No
# 26                                                Yes
# 27                                                Yes
# 28                                                 No
# 29                                                Yes
#
#    "10. Do you use steroids in any form, oral, ointment, inhaler?"\n  IOP  \
# 0                                                  No                  28
# 1                                                 Yes                  26
# 2                                                  No                  12
# 3                                                 Yes                  21
# 4                                                 Yes                  21
# 5                                                  No                  32
# 6                                                 Yes                  27
# 7                                                 Yes                  24
# 8                                                  No                  37
# 9                                                 Yes                   9
# 10                                                Yes                  21
# 11                                                Yes                  24
# 12                                                Yes                  34
# 13                                                 No                  10
# 14                                                Yes                  12
# 15                                                 No                  39
# 16                                                 No                  26
# 17                                                 No                  22
# 18                                                 No                  13
# 19                                                Yes                  17
# 20                                                Yes                  31
# 21                                                 No                  10
# 22                                                Yes                  36
# 23                                                Yes                  18
# 24                                                Yes                  22
# 25                                                 No                  19
# 26                                                 No                  12
# 27                                                Yes                  31
# 28                                                 No                  10
# 29                                                Yes                  10
#
#                     suggestion  clusters
# 0               NEED A CHECKUP         1
# 1               NEED A CHECKUP         1
# 2   BETTER TO CONSULT A DOCTOR         0
# 3               NEED A CHECKUP         1
# 4               NEED A CHECKUP         1
# 5                    EMERGENCY         2
# 6               NEED A CHECKUP         1
# 7               NEED A CHECKUP         1
# 8                    EMERGENCY         2
# 9   BETTER TO CONSULT A DOCTOR         0
# 10              NEED A CHECKUP         1
# 11              NEED A CHECKUP         1
# 12                   EMERGENCY         2
# 13  BETTER TO CONSULT A DOCTOR         0
# 14  BETTER TO CONSULT A DOCTOR         0
# 15                   EMERGENCY         2
# 16              NEED A CHECKUP         1
# 17              NEED A CHECKUP         1
# 18  BETTER TO CONSULT A DOCTOR         0
# 19  BETTER TO CONSULT A DOCTOR         0
# 20                   EMERGENCY         2
# 21  BETTER TO CONSULT A DOCTOR         0
# 22                   EMERGENCY         2
# 23  BETTER TO CONSULT A DOCTOR         1
# 24              NEED A CHECKUP         1
# 25  BETTER TO CONSULT A DOCTOR         1
# 26  BETTER TO CONSULT A DOCTOR         0
# 27                   EMERGENCY         2
# 28  BETTER TO CONSULT A DOCTOR         0
# 29  BETTER TO CONSULT A DOCTOR         0
